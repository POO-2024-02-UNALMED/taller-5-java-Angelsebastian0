# %% [markdown]
# **Ejercicio 1**

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)
#
#
#
# </center>

# %% [markdown]
# **¿Es correcta esta estructura proporcioniada en la imagen? ¿Si le falta algo, que sería?**

# %% [markdown]
# <center>

# %% [markdown]
# <center>

# %% [markdown]
# **Ejercicio 2**

# %% [markdown]
# **Notas importantes**

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
#
#
# </center>

# %% [markdown]
# **Analice el siguiente ejercicio y cambie los lugares con **, con el valor que debería ir, para que funcione, cumpla con el encapsulamiento y tenga un uso
# correcto de los módulos.**

# %% [markdown]
# **Nota:** La estructura de los archivos es:

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
# </center>

# %% [markdown]
# 🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻

# %% [markdown]
# **La salida esperada es la siguiente:**

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)
#
#
#
# </center>

# %% [markdown]
# 🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻

# %% [markdown]
# **Archivo main.py**

# %% [markdown]
# 🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻

# %%
"""
from dispositivos.celular import Celular # Celular se importara de la clase celular del archivo celular.py
from almacenamiento.almacenamientoExterno import AlmacenamientoExterno #porque el archivo almacenamientoExterno esta dentro de la carpeta almacenamiento
from dispositivos.computador import Computador #porque Computador puede ser un atriuto, metodo o clase del archivo computador.py
from almacenamientos.ram import Ram
from almacenamientos.almacenamiento import Almacenamiento

if *__name__* == " main ": # debe ser __name__ = "__main__"


  cel = Celular("Alejandro", "Realme 8 pro", Almacenamiento(128, "SSD"))# parametros correctos
  alm = AlmacenamientoExterno("Curso POO")
  pc = Computador("Lenovo", "s330", Almacenamiento(2000, "HDD"), Ram(8, "DDR4"))
  pc.setConexion(cel) # conecta el pc con el celular
  print(pc.getConexion())
  print("Cantidad de celulares: " + int(Celular.getCantidad()) # llamar el metodo getCantidad de la clase Celular
  print("Cantidad de almacenamientos externos: " + str(AlmacenamientoExterno.getCantidad())#llama el metodo getCantidad de la clase AlmacenamientoExterno
  print("Cantidad de computadores: " + str(Computador.getCantidad())#llama el metodo getCantidad de la clase Computador
  print(dir(Computador))# se usa dir para mostrar para mostrar los metodos y atributos de la clase Computador

# %% [markdown]
# **Archivo almacenamiento.py**

# %%
"""
#class Almacenamiento: # definimos la clase

  #def __init__ (self, tamano, tipo):# constructor para definir tamaño y tipo
    #self._TAMANO = tamano
    #self.tipo = tipo

  #def getTamano(self): # metodo para obtener TAMANO del almacenamiento
    #return self._TAMANO

  #def setTamano(self, tamano):#metodo para modificar el valor de TAMANO
    #self TAMANO = tamano # asignar valor

"""

# %% [markdown]
# 🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻

# %% [markdown]
# **Archivo ram.py**

# %%
"""
class Ram:

 #def init (self, tamano, tipoModulo): # Constructor para definir tamaño y tipo de módulo de la RAM
   #self._TAMANO = tamano #Asigna el tamaño de la ram
   #self._tipoModulo = tipoModulo

 def setTipoModulo(self, tipoModulo):
   #self._tipoModulo = tipoModulo # Asigna el nuevo tipo privado

 def getTipoModulo(self):
   return self._tipoModulo

 def getTamano(self):
   #return self._TAMANO # Retorna el tamaño de la RAM
"""

# %% [markdown]
# 🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻

# %% [markdown]
# **Archivo almacenamientoExterno.py**

# %%
"""
from almacenamientos.almacenamiento import Almacenamiento # Importación correcta de Almacenamiento

class AlmacenamientoExterno:
 _cantidad = 0 # Atributo privado de clase que lleva el conteo de instancias

 def __init__ (self, nombre):
   self._nombre = nombre
   self._almacenamiento = Almacenamiento(1000, "HDD")
   #AlmacenamientoExterno._cantidad += 1 # Incrementa la cantidad de instancias de AlmacenamientoExterno

 #def setNombre(self, nombre): # Método setter para cambiar el nombre
   #self._nombre = nombre # Asigna un nuevo nombre

 #def getNombre(self): # Método getter para obtener el nombre
   #return self._nombre # Retorna el nombre del almacenamiento externo

 def setAlmacenamiento(self, almacenamiento):
   self._almacenamiento = almacenamiento

 def getAlmacenamiento(self):
   return self._almacenamiento

 @classmethod #
 #def getCantidad(cls):
   #return cls._cantidad
"""

# %% [markdown]
# 🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻

# %% [markdown]
# **Archivo celular.py**

# %% [markdown]
# 🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻🤐🫣🧸🦠👩‍💻🧑‍💻🤐🥴🫣🧸🦠👩‍💻🧑‍💻

# %%
"""
class Celular:
 _cantidad = 0

 #def __init__(self, dueno, modelo, almacenamiento): # Constructor completo con el __init__
   #self._dueno = dueno # Inicializa el dueño del celular haciendo referencia a si mismo
   #self._modelo = modelo # Inicializa el modelo del celular
   #self._almacenamiento = almacenamiento # Inicializa el objeto de almacenamiento asociado
   #Celular._cantidad += 1 # Incrementa la cantidad de instancias de Celular

 #classmethod # Método de clase para obtener la cantidad de instancias
 #def getCantidad():
   #return cls._cantidad # Retorna el número total de instancias creadas de la clase
"""

# %% [markdown]
# **Archivo computador.py**

# %%
"""
from dispositivos.celular import Celular
from dispositivos.almacenamientoExterno import AlmacenamientoExterno
class Computador:
 #_Computador_cantidad = 0 # Atributo privado de clase que lleva el conteo de instancias

 def init (self, marca, modelo, almacenamiento, ram):
   self._marca = marca
   self._modelo = modelo
   self.almacenamiento = almacenamiento
   self.ram = ram
   #self._conectado = None # Inicializa como None para indicar que no hay conexión
   Computador._Computador cantidad += 1

 def setMarca(self, marca):
   self._marca = marca

  def getMarca(self):
   return self._marca

 def getModelo(self):
   return self._modelo

 def setConexion(self, dispositivo):
   self._conectado = dispositivo

 def getConexion(self):
   if(isinstance(self._conectado, Celular)):
     return "Celular " + self._conectado.modelo
   elif(isinstance(self._conectado, AlmacenamientoExterno)):
     return "Almacenamiento " + self._conectado.getNombre
"""
